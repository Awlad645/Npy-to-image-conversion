# %%
import numpy as np

# Load the .npy file
image_array = np.load('/content/1_3_6_1_4_1_14519_5_2_1_6279_6001_105495028985881418176186711228.npy')

# Slice the array
slice_1 = image_array[0, :, :, :]  # Slice from the first image in the first dimension
slice_2 = image_array[1, :, :, :]  # Slice from the second image in the first dimension

# Print the shapes of the slices
print("Shape of slice 1:", slice_1.shape)
print("Shape of slice 2:", slice_2.shape)
# Out:
# Shape of slice 1: (64, 64, 64)
# Shape of slice 2: (64, 64, 64)

# %%
from PIL import Image
import numpy as np
#data = np.load('/content/1_3_6_1_4_1_14519_5_2_1_6279_6001_105495028985881418176186711228.npy')
data=slice_1
data.shape
# Out:
# (64, 64, 64)

# %%
from matplotlib import pyplot as plt

for i in range(len(data)):
  plt.imshow(data[i], cmap='gray')
  plt.show()

# %%
from matplotlib import pyplot as plt

for i in range(len(slice_2)):
  plt.imshow(slice_2[i], cmap='gray')
  plt.show()
